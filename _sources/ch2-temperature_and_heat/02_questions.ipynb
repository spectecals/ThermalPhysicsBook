# %% [markdown]
# ### Questions

# %% [markdown]
# 1. The world’s power consumption is currently around 20 TW, and growing! (1 TW = 10<sup>12</sup>W.) Burning one ton of crude oil (which is nearly seven barrels worth) produces about 42 GJ (1 GJ= 10<sup>9</sup>J). If the world’s total power needs were to come entirely from burning oil (a large fraction currently does), how much oil would we be burning per second?
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 2. The molar heat capacity of gold is 25.4 Jmol<sup>−1</sup>K<sup>−1</sup>. Its density is 19.3×10<sup>3</sup> kgm<sup>−3</sup>. Calculate:
# - the specific heat capacity of gold,
# - the heat capacity per unit volume,
# - and the heat capacity of 4×10<sup>6</sup> kg of gold? (This is roughly the holdings of Fort Knox.)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 3. Explain the differences and similarities between the definitions of the kelvin and Celsius temperature scales. (5)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 4. The triple point of CO2 is at 5.11 atm and 216.6 K. Describe the phase changes that occur in a sample of CO2 when:
# - The temperature increases from 200 K to 273 K at 1 atm.
# - The temperature increases from 200 K to 273 K at 100 atm.
# - The pressure is reduces from 100 atm to 1 atm at 273 K.
# Include sketches to show these phase changes relative to the phase boundaries. (5)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 5. What is the minimum quantity of ice at -10C you need to bring 500 g of liquid water at 60C to 0C? (5)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 6. **EXAMPLE 17.12 from University Physics with Modern Physics, pg. 573.** A 10cm steel bar is welded to a 20cm copper bar. Each bar has a square cross section, 2cm on each side. The free end of the steel bar is kept at 100 $^\circ C$ by placing it in contact with steam, and the free end of the copper bar is kept at 0 $^\circ C$ by placing it in contact with ice. Both bars are perfectly insulated on their sides. Find
# - the steady-state temperature at the junction of the two bars,
# - and the total rate of heat flow through the bars.
# Note: you will need the thermal conductivities of steel ($50.2 \text{W / m} \cdot\text{ K}$) and copper ($385 \text{W / m} \cdot\text{ K}$).
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 7. **EXAMPLE 17.15 from University Physics with Modern Physics, pg. 575.** The emissivity of the human body is very close to unity, irrespective of skin pigmentation.
# - What is the total rate of radiation of energy from a human body with surface area $1.20\,\text{m}^2$ and surface temperature $30^\circ\text{C} = 303\,\text{K}$?
# - If the surroundings are at a temperature of $20^\circ\text{C}$, what is the net rate of radiative heat loss from the body?
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
