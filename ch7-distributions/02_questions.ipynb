# %% [markdown]
# ### Questions

# %% [markdown]
# 1. Explain the mean free path for molecules in a gas. (3 Marks)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 2. The mean free path is given by
#    $$l = \frac{1}{\sqrt{2}\pi d^2 N_v}$$
#    where \( d \) is the diameter of the molecule, and \( N_v \) is the number per unit volume. If the mean free path is equal to 200 nm, \( d = 0.2 \, \text{nm} \), and the gas is at standard atmospheric pressure, what is the temperature of the gas? (4 Marks)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 3. Sketch the number density of air molecules as a function of height above sea level. (2 Marks)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 4. What is the number density of air molecules at an altitude of 11 km compared to the number density at sea level? You can assume a constant temperature at both heights, and the average molecular mass is \( 4.8 \times 10^{-26} \, \text{kg} \). (4 Marks)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 5. Define the binomial and Poisson distributions, and explain the differences between them. (4 Marks)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 6. The number of molecules in a small volume of a gas follows a Poisson distribution. (6 Marks)
#
#    1. If the mean number of molecules in the volume is 3.5, what is the probability that there are exactly 3 molecules?
#    2. What is the probability there is at least one molecule?
#    3. Draw the Poisson distribution for the case above.
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 7. Consider a tiny volume of gas with 3 identical molecules that can occupy 10 different locations within the gas. If all locations contain at most one molecule, estimate the entropy associated with the gas. (4 Marks)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 8. Sketch the range of velocities given by the Maxwell–Boltzmann distribution for two gases, one at 300 K and one at 500 K. Identify the average velocity, the most probable velocity, and the root mean square velocity. (4 Marks)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 9. Explain the consequences of the Pauli exclusion principle as applied to fermions and bosons. (3 Marks)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 10. Sketch the energy dependence of the Fermi–Dirac distribution for a range of temperatures including absolute zero,
#     $$
#     f(E) = \frac{1}{e^{(E - E_F)/k_B T} + 1}
#     $$
#     for a range of temperatures. What is the value of \( f(E) \) when \( E = E_F \)? (4 Marks)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
