# %% [markdown]
# ### Questions
#
# 1. What is the mass of 3 moles of carbon dioxide (CO<sub>2</sub>)?
#
#    <RAW HTML BREAK>
#    <br><br>
#    </RAW HTML BREAK>
#
# 2. A typical bacterium has a mass of 10<sup>−12</sup> g. Calculate the mass of a mole of bacteria. (Interestingly, this is about the total number of bacteria living in the guts of all humans resident on planet Earth.) Give your answer in units of elephant-masses (elephants have a mass ~5000 kg).
#
#    <RAW HTML BREAK>
#    <br><br>
#    </RAW HTML BREAK>
#
# 3. Are there more water *molecules* in your body (assuming you are 100% water) or more water *droplets* in all the oceans in the world? There is approximately 10<sup>21</sup> kg of water in all of the world's oceans. Use an estimate of the size of a typical droplet of water.
#
#    <RAW HTML BREAK>
#    <br><br>
#    </RAW HTML BREAK>
#
# 4. A system contains $n$ atoms, each of which can only have zero or one quanta of energy. How many ways can you arrange $r$ quanta of energy among these atoms when:
#     1. $n=20,\ r=10$?
#     2. $n=2*10^{23},\ r=10^{23}$?
#
#    <RAW HTML BREAK>
#    <br><br>
#    </RAW HTML BREAK>
#
# 5. A gas is in thermal equilibrium before being compressed.
#     1. What type of variables are used to describe its state?
#     2. Give three examples of these variables.
#     3. After the gas is compressed, what condition must be satisfied for these variables to be well defined again?
#     4. How do the thermodynamic variables change when the gas is compressed?
#     5. Why can these variables not be used to describe the gas during the compression itself?
#
#    <RAW HTML BREAK>
#    <br><br>
#    </RAW HTML BREAK>
#
# 6. Calculate the entropy of a 6-sided die that has:
#    1. a $\frac{1}{6}$ chance to roll any face.
#    2. a $\frac{2}{6}$ chance to roll a 1, 2 or 3, and no chance for 4, 5 or 6.
