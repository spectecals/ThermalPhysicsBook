# %% [markdown]
# # 2013 Past Paper Questions

# %% [markdown]
# 1. What is the triple point of a material? (1)
#
#    Draw the pressure-temperature phase diagram for water. The triple point of water is at a pressure of $0.006\ \text{atm}$ and temperature of $0.01^\circ\text{C}$. On the graph, indicate the phase changes corresponding to sublimation, evaporation, and freezing. (6)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 2. The entropy of an unfair coin that has a probability of landing heads $p_H = 0.9$ is to be calculated using $\log_2$, and in this case the entropy is dimensionless.
#
#    1. What is the entropy of the coin? (4)
#    2. What are the units of thermodynamic entropy? (1)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 3. Using SI unit quantities, what are the dimensions of the universal gas constant $R$? (3)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 4. An ideal gas undergoes a cyclic process that is made up of an isothermal expansion from $V_1$ to $V_2$, an isobaric compression from $V_2$ to $V_1$, and finally an isovolumetric pressure increase back to the initial state.
#
#    1. Draw the above process on a $PV$ diagram. (6)
#    2. What is the total change in internal energy in this process? (1)
#    3. In terms of state variables ($P$, $T$, $V$, etc.), give the work done by (or on) the gas during each stage, and at each stage state whether the work by (or on) is positive, negative or zero. Be clear as to whether your answer is given for “work by” or “work on”. (7)
#    4. What is the significance of reversing the cycle? (1)
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 5. You pour a $330\ \text{ml}$ can of coke into a glass on a hot day. You leave the glass out in the sun, so the temperature of the coke rises to $32^\circ\text{C}$. You would like to drink the coke, but not until your drink is cold. You use ice from your freezer at $-10^\circ\text{C}$ to bring the temperature of your drink down to $5^\circ\text{C}$.
#
#    1. What is the minimum mass of ice that is required to bring the temperature of the drink down to $5^\circ\text{C}$? Explain any additional assumptions that you have made in this calculation. (10)
#    2. Explain the difference between the units of specific heat capacity and heat capacity. (1)
#    3. Explain the difference between the units of specific heat capacity and specific latent heat. (1)
#
#     Assume that the specific heat capacities of coke and liquid water are the same, $(4.2\ \text{kJ kg}^{-1}\text{K}^{-1})$. The specific heat capacity of ice is $2.11\ \text{kJ kg}^{-1}\text{K}^{-1}$, and the specific latent heat of fusion of water is $333\ \text{kJ kg}^{-1}$. Assume that equal volumes of coke and water have the same mass.
#
# <RAW HTML BREAK>
# <br><br>
# </RAW HTML BREAK>
#
# 6. $1.00\ \text{g}$ of water vapourises isobarically at atmospheric pressure $(1.013 \times 10^5\ \text{Pa})$. Its volume in the liquid state is $V_{\text{liquid}} = 1.00\ \text{cm}^3$, and its volume in the vapour state is $V_{\text{vapour}} = 1671\ \text{cm}^3$.
#
#    1. Find the work done by the gas in the expansion. (3)
#    2. Find the change in internal energy of the system. (5)
#
#    Ignore any mixing of the steam and the surrounding air — the steam simply pushes the surrounding air out of the way. The latent heat of vapourisation for water is $2260\ \text{kJ kg}^{-1}$, and $1\ \text{cm}^3 = 1 \times 10^{-6}\ \text{m}^3$.
